# %% [markdown]
# # Natural Language Processing - Assignment 1
# ### Cross-Cultural Knowledge Evaluation
#
# **Student Name**: (John) Paul Nagle
# **Student ID**: R00065426
# **Model**: Mistral-7B-Instruct-v0.3 (Or )
# **Locales**: US, UK, Chinese, Ethopian

# %% [markdown]
# ## Setup and Installation
#
# If we are running in colab mount google drive with the data files. Otherwise, use the local path.

# %%
try:
  import google.colab
  IN_COLAB = True
  print("Running in colab...")
  from google.colab import drive
  drive.mount('/content/drive')
  REQS_PATH="/content/drive/MyDrive/Colab Notebooks/nlp_assignment_1/requirements.txt"
  DATA_FILES_PATH="/content/drive/MyDrive/Colab Notebooks/nlp_assignment_1/data"
except:
  IN_COLAB = False
  print("Running in local environment...")
  REQS_PATH="requirements.txt"
  DATA_FILES_PATH="data"
# Out:
# Running in colab...
# Mounted at /content/drive

# %%
# Install required packages
# !pip install -r "{REQS_PATH}" -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.8/120.8 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 118.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 5.9 MB/s eta 0:00:00

# %% [markdown]
# ## Imports and Configuration

# %%
import warnings
import re
import unicodedata
import json
import random
import numpy as np
import pandas as pd
from typing import Dict,  Optional

# US and GB locale stemming/lemmatization
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# Amharic specific
from amharicNLP.resources.cleaner import AmharicCleaner
from amharicNLP.resources.normalizer import AmharicNormalizer
from amharicNLP.resources.lemmatizer import AmharicLemmatizer
from amharicNLP.resources.stemmer import AmharicStemmer
from amharicNLP.resources.stopwrod import AmharicStopwordProcessor
from amharicNLP.resources.tokenizer import AmharicWordTokenizer


import torch
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)

warnings.filterwarnings("ignore")

# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# Original Text: በአገራችን ኢትዮጵያ <h1/> �ላ ያሉ ተማሪዎች በትምህርት ላይ ትኩረት ማድረግ አለባቸው። 123 ቁጥር! በላይ ዘለቀ ጀግና የኢትዮጵያ አርበኛ ነበር።
#
# After HTML Removal: በአገራችን ኢትዮጵያ  �ላ ያሉ ተማሪዎች በትምህርት ላይ ትኩረት ማድረግ አለባቸው። 123 ቁጥር! በላይ ዘለቀ ጀግና የኢትዮጵያ አርበኛ ነበር።
#
# After Cleaning: በአገራችን ኢትዮጵያ ላ ያሉ ተማሪዎች በትምህርት ላይ ትኩረት ማድረግ አለባቸው። 123 ቁጥር! በላይ ዘለቀ ጀግና የኢትዮጵያ አርበኛ ነበር።
#
# After Normalization: በአገራችን ኢትዮጵያ ላ ያሉ ተማሪዎች በትምህርት ላይ ትኩረት ማድረግ አለባቸው ።  123 ቁጥር !  በላይ ዘለቀ ጀግና የኢትዮጵያ አርበኛ ነበር ።
#
# After Stopword Removal: ['በአገራችን', 'ኢትዮጵያ', 'ተማሪዎች', 'በትምህርት', 'ትኩረት', 'አለባቸው', '።', '123', 'ቁጥር', '!', 'በላይ', 'ዘለቀ', 'ጀግና', 'የኢትዮጵያ', 'አርበኛ', 'ነበር', '።']
#
# After Lemmatization: በአገራችን ኢትዮጵያ <h1/> �ላ ያሉ ተማሪዎች በትምህርት ላይ ትኩረት ማድረግ አለባቸው። 123 ቁጥር! በላይ ዘለቀ ጀግና የኢትዮጵያ አርበኛ ነበር።
#
# After Stemming: ['በአገረቸነ', 'ኢትዮጵያ', 'ተመረወቸ', 'ተበላለጠ', 'ተከረተ', 'አለበቸወ', '።', '123', 'ቀጠረ', '!', 'በለየ', 'ዘለቀ', 'ጎበዝ', 'የአተየጰየ', 'አረበኘ', 'ነበረ', '።']
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# CUDA device: Tesla T4

# %% [markdown]
# ## Locale Configuration
#
# Selected locales:
# - **en-US** (English-US): High-resource baseline
# - **en-GB** (English-UK): High-resource, European locale
# - **zh-CN** (Chinese-China): Non-Latin script, major language
# - **am-ET** (Amharic-Ethiopia): Low-resource, under-represented locale

# %%
# Define locales
LOCALES = {
    'en-US': {
        'code': 'en-US',
        'name': 'English (United States)',
        'language': 'English',
        'script': 'Latin',
        'resource_level': 'high'
    },
    'en-GB': {
        'code': 'en-GB',
        'name': 'English (United Kingdom)',
        'language': 'English',
        'script': 'Latin',
        'resource_level': 'high'
    },
    'zh-CN': {
        'code': 'zh-CN',
        'name': 'Chinese (China)',
        'language': 'Simplified Chinese',
        'script': 'Han',
        'resource_level': 'high'
    },
    'am-ET': {
        'code': 'am-ET',
        'name': 'Amharic (Ethiopia)',
        'language': 'Amharic',
        'script': 'Ethiopic',
        'resource_level': 'low'
    }
}

print("Configured Locales:")
for locale_code, config in LOCALES.items():
    print(f"  {locale_code}: {config['name']} ({config['script']} script, {config['resource_level']}-resource)")
# Out:
# Configured Locales:
#   en-US: English (United States) (Latin script, high-resource)
#   en-GB: English (United Kingdom) (Latin script, high-resource)
#   zh-CN: Chinese (China) (Han script, high-resource)
#   am-ET: Amharic (Ethiopia) (Ethiopic script, low-resource)

# %% [markdown]
# ## Load mistralai/Mistral-7B-Instruct-v0.3 Model (or TinyLlama/TinyLlama-1.1B-Chat-v1.0 if on cpu)
#
# **Hardware Detection & Model Loading Strategy:**
# - GPU available i.e. running on colab: Use 4-bit quantization with Mistral-7B
# - CPU only: Use smaller model (TinyLlama-1.1B) for faster testing./debugging

# %%
TEMPERATURE = 0.0  # Required for reproducibility
MAX_NEW_TOKENS = 100 # Maximum number of tokens to generate ????

# Configure model loading based on hardware
if torch.cuda.is_available():
    MODEL_NAME = "mistralai/Mistral-7B-Instruct-v0.3"  # 7B params
    # GPU: Use 4-bit quantization
    quantization_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True,
    )

    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=quantization_config,
        device_map="auto",
        trust_remote_code=True
    )
    print(f"✓ Model {MODEL_NAME} loaded with 4-bit quantization on GPU")

else:
    MODEL_NAME = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"  # 1.1B params, faster on CPU
    # No quantization
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        torch_dtype=torch.float32,  # Use float32 for CPU
        device_map="cpu",
        trust_remote_code=True,
        low_cpu_mem_usage=True
    )
    print("✓ Model loaded on CPU (float32)")

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"

model.eval()
print(f"✓ Model: {MODEL_NAME}")
print(f"✓ Device: {'GPU' if torch.cuda.is_available() else 'CPU'}")
print(f"✓ Temperature: {TEMPERATURE} (deterministic)")
print(f"✓ Max new tokens: {MAX_NEW_TOKENS}")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ✓ Model mistralai/Mistral-7B-Instruct-v0.3 loaded with 4-bit quantization on GPU
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# ✓ Model: mistralai/Mistral-7B-Instruct-v0.3
# ✓ Device: GPU
# ✓ Temperature: 0.0 (deterministic)
# ✓ Max new tokens: 100

# %% [markdown]
# ## Text Normalization
#
# Robust normalization strategy for multilingual text matching.

# %%
class TextNormalizer:
    """Multi-stage text normalization for answer matching."""

    def __init__(self):
        self.normalization_form  = 'NFC'  # Unicode normalization form

        # Download required NLTK data (run once)
        try:
            nltk.data.find('corpora/wordnet')
        except LookupError:
            nltk.download('wordnet')
            nltk.download('omw-1.4')
        self.lemmatizer = WordNetLemmatizer()

    def normalize(self, text: str, locale: Optional[str] = None) -> str:
        """Normalize text for multilingual text matching with some hard-coded locale-specific handling."""
        if not text:
            return ""

        # 1. Unicode normalization (NFC - Canonical Composition)
        text = unicodedata.normalize(self.normalization_form, text)

        # 2. Remove control characters
        text = re.sub(r'[\x00-\x08\x0B-\x0C\x0E-\x1F\x7F-\x9F]', '', text)

        # 3. Normalize line breaks to \n
        text = text.replace('\r\n', '\n').replace('\r', '\n')

        # 4. Locale-specific whitespace normalization
        if locale == 'zh-CN':
            # Chinese: Remove ALL whitespace (Chinese doesn't use spaces between words)
            text = re.sub(r'\s+', '', text)
        else:
            # Other locales: Standard whitespace normalization
            text = re.sub(r'[ \t]+', ' ', text)
            text = re.sub(r'\s+', ' ', text)
            text = re.sub(r'\n{3,}', '\n\n', text)
            text = text.strip()

        # 5. Convert to lower case (safe for all locales)
        text = text.lower()

        # 6. Locale-specific punctuation handling
        if locale == 'zh-CN':
            # Chinese: Remove both Latin and Chinese punctuation
            # Keep Chinese characters, numbers, and basic Latin letters
            text = re.sub(r'[^\w\u4e00-\u9fff]', '', text, flags=re.UNICODE)
        elif locale == 'am-ET':
            # Amharic:
            # From https://github.com/yonasab12/amharicNLP
            # Cleaning: HTML removal and Numbers & non-Amharic characters cleaned
            cleaner = AmharicCleaner()
            cleaned_html = cleaner.remove_html(text)
            cleaned_text = cleaner.remove_noise(cleaned_html)

            # Normalization
            normalizer = AmharicNormalizer()
            text1 = normalizer.normalize_amharic_chars(cleaned_text)
            text2 = normalizer.normalize_punctuation_spacing(text1)
            text3 = normalizer.expand_abbreviations(text2)
            # ✔️ Standardized characters ✔️ Clean punctuation spacing

            # Stopword removal : Removes high-frequency filler words
            stopword_processor = AmharicStopwordProcessor()
            filtered_text = stopword_processor.remove(text3)

            # Lemmatization : Converts words to canonical dictionary forms
            lemmatizer = AmharicLemmatizer()
            text = lemmatizer.lemmatize(filtered_text)
            # Reference answers are likely in proper Amharic word forms, not stems, so
            # we skip stemming .

        else:
            # GB and US locales: Remove punctuation but keep apostrophes and hyphens for contractions
            text = re.sub(r'[^\w\s\'\-]', '', text)

            # Lemmatize each word (prevents word meaning better than stemming)
            words = text.split()
            lemmatized_words = [self.lemmatizer.lemmatize(word, pos='v') for word in words]
            lemmatized_words = [self.lemmatizer.lemmatize(word, pos='n') for word in lemmatized_words]
            text = ' '.join(lemmatized_words)

        return text

# Initialize normalizer
normalizer = TextNormalizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %% [markdown]
# ## Base Class for Question System
# Base class for all question-answering systems with shared generation logic.

# %%
class BaseQuestionSystem():
    """Base class for question-answering systems with shared generation logic."""

    def __init__(self, model, tokenizer, temperature=0.0, max_new_tokens=100):
        """Initialize base system with model and generation parameters."""
        self.model = model
        self.tokenizer = tokenizer
        self.temperature = temperature
        self.max_new_tokens = max_new_tokens

    def generate_response(self, prompt: str, return_confidence: bool = False):
        """Generate response from model given a prompt. """
        # Tokenize
        inputs = self.tokenizer(
            prompt,
            return_tensors="pt",
            padding=True,
            truncation=True
        ).to(self.model.device)

        # Generate with scores if confidence requested
        with torch.no_grad():
            if return_confidence:
                outputs = self.model.generate(
                    **inputs,
                    max_new_tokens=self.max_new_tokens,
                    temperature=self.temperature,
                    max_length=None,
                    do_sample=False,
                    pad_token_id=self.tokenizer.eos_token_id,
                    eos_token_id=self.tokenizer.eos_token_id,
                    output_scores=True,
                    return_dict_in_generate=True
                )

                # Calculate confidence from token probabilities
                scores = outputs.scores
                if scores:
                    # Get probability of selected token at each step
                    probs = []
                    for score in scores:
                        prob = torch.softmax(score, dim=-1).max().item()
                        probs.append(prob)
                    confidence = sum(probs) / len(probs) if probs else 0.0
                else:
                    confidence = 0.0

                # Decode
                generated_tokens = outputs.sequences[0][inputs['input_ids'].shape[1]:]
                response = self.tokenizer.decode(generated_tokens, skip_special_tokens=True)

                return response, confidence
            else:
                # Original behavior
                outputs = self.model.generate(
                    **inputs,
                    max_new_tokens=self.max_new_tokens,
                    temperature=self.temperature,
                    max_length=None,
                    do_sample=False,
                    pad_token_id=self.tokenizer.eos_token_id,
                    eos_token_id=self.tokenizer.eos_token_id
                )

                generated_tokens = outputs[0][inputs['input_ids'].shape[1]:]
                response = self.tokenizer.decode(generated_tokens, skip_special_tokens=True)

                return response

    def should_abstain(self, confidence: float, threshold: float = 0.3) -> bool:
        """Determine if model should abstain based on confidence."""
        return confidence < threshold

    def create_prompt(self, *args, **kwargs) -> str:
        """Create prompt for the model. Must be implemented by subclasses."""
        return ""

    def generate_answer(self, *args, **kwargs) -> Dict:
        """Generate answer for a question. Must be implemented by subclasses."""
        return {}

    def evaluate_answer(self, *args, **kwargs) -> bool:
        """Evaluate generated answer. Must be implemented by subclasses."""
        return True

print("✓ Base Question System class defined")
# Out:
# ✓ Base Question System class defined

# %% [markdown]
# ## Baseline SAQ System
# ### Track A: Short Answer Questions (SAQ)
# Direct prompting baseline with locale-aware generation and persona prompting.

# %%
class BaselineSAQSystem(BaseQuestionSystem):
    """Baseline Short Answer Question system using direct prompting."""
    def __init__(self, model, tokenizer, normalizer, temperature=0.0):
        super().__init__(model, tokenizer, temperature, max_new_tokens=100)
        self.normalizer = normalizer

    def create_prompt(self, question: str, locale: str) -> str:
        """ Create a prompt for the model. """
        locale_config = LOCALES.get(locale)
        if not locale_config:
            raise ValueError(f"Unknown locale: {locale}")

        # Define persona based on locale
        personas = {
            'en-US': "You are an American cultural expert with deep knowledge of US everyday life, food, traditions, and customs.  You answer simply and directly, with no explanation just the simple,direct answer.",
            'en-GB': "You are a British cultural expert with deep knowledge of UK everyday life, food, traditions, and customs. You answer simply and directly, with no explanation just the simple,direct answer.",
            'zh-CN': "You are a Chinese cultural expert with deep knowledge of Chinese everyday life, food, traditions, and customs. You answer simply and directly, with no explanation just the simple,direct answer.",
            'am-ET': "You are an Ethiopian cultural expert with deep knowledge of Ethiopian everyday life, food, traditions, and customs. You answer simply and directly, with no explanation just the simple,direct answer."
        }

        persona = personas.get(locale, "You are a cultural expert.  You answer simply and directly, with no explanation just the simple,direct answer.")

        # TinyLlama chat format
        if "TinyLlama" in MODEL_NAME:
            prompt = f"""<|system|>
                        {persona}.
                        Answer the following question about {locale_config['name']} culture and everyday knowledge.
                        Provide a short, direct answer in {locale_config['language']}.</s>
                        <|user|>
                        {question}</s>
                        <|assistant|>
                        """
        else:
            # Mistral/Llama format
            prompt = f"""[INST] {persona}. Answer the following question about {locale_config['name']} culture and everyday knowledge.
                        Provide a short, direct answer in {locale_config['language']}.
                        You answer simply and directly, with no explanation just the simple, direct answer.
                        Question: {question}

                        Answer: [/INST]
                      """

        return prompt

    def generate_answer(self, question: str, locale: str, return_confidence: bool = True) -> Dict:
        """ Generate answer for a question in the specified locale. """
        # Normalize question
        question = self.normalizer.normalize(question)

        # Create prompt
        prompt = self.create_prompt(question, locale)

        # Generate response with confidence
        if return_confidence:
            answer, confidence = self.generate_response(prompt, return_confidence=True)
        else:
            answer = self.generate_response(prompt, return_confidence=False)
            confidence = None

        # Normalize answer
        answer = self.normalizer.normalize(answer)

        result = {
            'question': question,
            'locale': locale,
            'answer': answer,
            'raw_output': answer,
            'prompt': prompt
        }

        if confidence is not None:
            result['confidence'] = confidence

        return result

    def evaluate_answer(self, generated_answer: str, question_id: str, reference_data: dict, locale: str = None) -> bool:
        """Evaluate if generated answer matches any reference answer."""
        if question_id not in reference_data:
            return False

        # Get all acceptable answers for this question
        annotations = reference_data[question_id]['annotations']

        # Normalize generated answer with locale-specific handling
        normalized_generated = self.normalizer.normalize(generated_answer, locale=locale)

        # Check against all acceptable answers
        for annotation in annotations:
            for reference_answer in annotation['answers']:
                normalized_reference = self.normalizer.normalize(reference_answer, locale=locale)

                # Exact match after normalization
                if normalized_generated == normalized_reference:
                    return True

                # Substring match (generated contains reference or vice versa)
                if normalized_reference in normalized_generated or \
                   normalized_generated in normalized_reference:
                    return True

        return False

# Initialize baseline system
baseline_saq_system = BaselineSAQSystem(
    model=model,
    tokenizer=tokenizer,
    normalizer=normalizer,
    temperature=TEMPERATURE
)

print("✓ Baseline SAQ System initialized")
print(f"  Model: {MODEL_NAME}")
print(f"  Temperature: {TEMPERATURE}")
print(f"  Locales: {', '.join(LOCALES.keys())}")
# Out:
# ✓ Baseline SAQ System initialized
#   Model: mistralai/Mistral-7B-Instruct-v0.3
#   Temperature: 0.0
#   Locales: en-US, en-GB, zh-CN, am-ET

# %% [markdown]
# ## Load SAQ Questions with IDs
#
# Load SAQ questions along with their IDs for proper evaluation.

# %%
def load_saq_questions_with_ids(locale_code, num_questions=10):
    """Load questions with their IDs from CSV file"""
    locale_to_file = {
        'en-US': 'US_questions.csv',
        'en-GB': 'UK_questions.csv',
        'zh-CN': 'China_questions.csv',
        'am-ET': 'Ethiopia_questions.csv'
    }

    filename = locale_to_file.get(locale_code)
    if not filename:
        return []

    filepath = f'{DATA_FILES_PATH}/saq_questions/'

    try:
        df = pd.read_csv(f'{filepath}{filename}')
        # Return list of (question_id, question_text) tuples
        questions = [
            (row['ID'], row['Question'])
            for _, row in df.head(num_questions).iterrows()
        ]
        return questions
    except Exception as e:
        print(f"Error loading {filename}: {e}")
        return []

# %% [markdown]
# ## Load SAQ Reference Answers
#
# Load annotated reference answers from BLEND JSON files for evaluation.

# %%
# Load reference answers for each locale
def load_reference_answers(locale_code):
    """Load reference answers from JSON file for a locale"""
    locale_to_file = {
        'en-US': 'US_data.json',
        'en-GB': 'UK_data.json',
        'zh-CN': 'China_data.json',
        'am-ET': 'Ethiopia_data.json'
    }

    filename = locale_to_file.get(locale_code)
    if not filename:
        return {}

    filepath = f'{DATA_FILES_PATH}/saq_answers/'

    try:
        with open(f'{filepath}{filename}', 'r', encoding='utf-8') as f:
            return json.load(f)
    except Exception as e:
        print(f"Error loading {filename}: {e}")
        return {}

# Load all reference data
REFERENCE_ANSWERS = { locale: load_reference_answers(locale) for locale in LOCALES.keys() }

print("✓ Reference answers loaded")
for locale, data in REFERENCE_ANSWERS.items():
    print(f"  {locale}: {len(data)} questions")
# Out:
# ✓ Reference answers loaded
#   en-US: 500 questions
#   en-GB: 500 questions
#   zh-CN: 500 questions
#   am-ET: 500 questions

# %% [markdown]
# ## Evaluate SAQ Baseline System
#
# Run full evaluation across all locales and calculate accuracy metrics for SAQ.

# %%
# Evaluate saq baseline system
NUM_EVAL_QUESTIONS = 10  # Start with 10 questions per locale

saq_results = {locale: {'correct': 0, 'total': 0, 'details': []} for locale in LOCALES.keys()}

print("Evaluating Baseline SAQ System:")
print(f"Testing {NUM_EVAL_QUESTIONS} questions per locale\n")
print("="*80)

for locale in LOCALES.keys():
    print(f"\n{'='*80}")
    print(f"Locale: {locale} ({LOCALES[locale]['name']})")
    print(f"{'='*80}\n")

    # Load questions with IDs
    questions_with_ids = load_saq_questions_with_ids(locale, NUM_EVAL_QUESTIONS)

    for i, (question_id, question_text) in enumerate(questions_with_ids, 1):
        # Generate answer with confidence
        result = baseline_saq_system.generate_answer(question_text, locale, return_confidence=True)
        generated_answer = result['answer']
        confidence = result.get('confidence', 0.0)

        # Optional: Implement abstention based on confidence threshold
        CONFIDENCE_THRESHOLD = 0.3
        abstained = baseline_saq_system.should_abstain(confidence, CONFIDENCE_THRESHOLD)

        if abstained:
            generated_answer = "I don't know"

        # Evaluate answer
        is_correct = baseline_saq_system.evaluate_answer(
            generated_answer,
            question_id,
            REFERENCE_ANSWERS[locale],
            locale=locale
        )

        # Update results
        saq_results[locale]['total'] += 1
        if is_correct:
            saq_results[locale]['correct'] += 1

        # Store details with confidence
        saq_results[locale]['details'].append({
            'question_id': question_id,
            'question': question_text,
            'generated': generated_answer,
            'correct': is_correct,
            'confidence': confidence,
            'abstained': abstained
        })

        # Print result with confidence
        status = "CORRECT" if is_correct else "INCORRECT"
        abstain_marker = " [ABSTAINED]" if abstained else ""
        print(f"{i}. {status}{abstain_marker} [{question_id}] (confidence: {confidence:.3f})")
        print(f"   Q: {question_text}")
        print(f"   A: {generated_answer}")
        print("-"*80)

print(f"\n{'='*80}")
print("EVALUATION COMPLETE")
print(f"{'='*80}")
# Out:
# Evaluating Baseline SAQ System:
# Testing 10 questions per locale
#
# ================================================================================
#
# ================================================================================
# Locale: en-US (English (United States))
# ================================================================================
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 1. CORRECT [Al-en-01] (confidence: 0.919)
#    Q: What is a common snack for preschool kids in the US?
#    A: goldfish cracker or apple slice with peanut butter
# --------------------------------------------------------------------------------
# 2. CORRECT [Al-en-02] (confidence: 0.844)
#    Q: What is a popular food to go with beer in the US?
#    A: pretzel or pizza
# --------------------------------------------------------------------------------
# 3. CORRECT [Al-en-04] (confidence: 0.699)
#    Q: What is the most popular fruit in the US?
#    A: apple
# --------------------------------------------------------------------------------
# 4. CORRECT [Al-en-06] (confidence: 0.867)
#    Q: What is a common school cafeteria food in the US?
#    A: pizza hamburger taco chicken nugget and macaroni cheese be common school cafeteria food in the u
# --------------------------------------------------------------------------------
# 5. CORRECT [Al-en-08] (confidence: 0.934)
#    Q: What are the most commonly eaten snacks at shopping malls in the US?
#    A: pretzel or popcorn
# --------------------------------------------------------------------------------
# 6. CORRECT [Al-en-09] (confidence: 0.834)
#    Q: What is a popular snack at an amusement park in the US?
#    A: pretzel or cotton candy
# --------------------------------------------------------------------------------
# 7. CORRECT [Al-en-16] (confidence: 0.768)
#    Q: At what age do kids start preschool in the US? (Provide Arabic numerals (e.g., 12) only.)
#    A: 3 or 4 depend on the area and school
# --------------------------------------------------------------------------------
# 8. CORRECT [Al-en-17] (confidence: 0.841)
#    Q: What is a popular afterschool sport for elementary schools in the US?
#    A: soccer or soccerfootball be a popular afterschool sport for elementary school in the u
# --------------------------------------------------------------------------------
# 9. CORRECT [Al-en-18] (confidence: 0.760)
#    Q: For which subject do elementary students get private education in the US?
#    A: private education in the u be typically provide for subject such a math read write science social study and sometimes foreign language however it can vary depend on the school and the family's preference some family may also seek private tutor for specific subject
# --------------------------------------------------------------------------------
# 10. CORRECT [Al-en-19] (confidence: 0.892)
#    Q: What is a popular second language for high school students in the US?
#    A: spanish
# --------------------------------------------------------------------------------
#
# ================================================================================
# Locale: en-GB (English (United Kingdom))
# ================================================================================
#
# 1. CORRECT [Al-en-01] (confidence: 0.870)
#    Q: What is a common snack for nursery kids in the UK?
#    A: cheese cracker or fruit eg apple banana be common snack for nursery kid in the uk
# --------------------------------------------------------------------------------
# 2. INCORRECT [Al-en-02] (confidence: 0.740)
#    Q: What is a popular food to go with beer in the UK?
#    A: pie and mash
# --------------------------------------------------------------------------------
# 3. CORRECT [Al-en-04] (confidence: 0.671)
#    Q: What is the most popular fruit in the UK?
#    A: apple
# --------------------------------------------------------------------------------
# 4. INCORRECT [Al-en-06] (confidence: 0.841)
#    Q: What is a common school cafeteria food in the UK?
#    A: pasta jacket potato sausage roll and fish finger be common school cafeteria food in the uk
# --------------------------------------------------------------------------------
# 5. CORRECT [Al-en-08] (confidence: 0.856)
#    Q: What are the most commonly eaten snacks at shopping malls in the UK?
#    A: crisp potato chip or chocolate
# --------------------------------------------------------------------------------
# 6. CORRECT [Al-en-09] (confidence: 0.792)
#    Q: What is a popular snack at an amusement park in the UK?
#    A: crisp potato chip or a hot dog
# --------------------------------------------------------------------------------
# 7. CORRECT [Al-en-16] (confidence: 0.806)
#    Q: At what age do kids start nursery in the UK? (Provide Arabic numerals (e.g., 12) only.)
#    A: 3 in some case a early a 2
# --------------------------------------------------------------------------------
# 8. CORRECT [Al-en-17] (confidence: 0.969)
#    Q: What is a popular afterschool sport for primary schools in the UK?
#    A: football soccer
# --------------------------------------------------------------------------------
# 9. CORRECT [Al-en-18] (confidence: 0.762)
#    Q: For which subject do primary school students get private education in the UK?
#    A: private education in the uk be often seek for subject such a math english science and sometimes language but it can also extend to other subject like art music or even sport depend on the school and the family's preference however it's important to note that private tutor be not limit to these subject and can cover a wide range of topic
# --------------------------------------------------------------------------------
# 10. CORRECT [Al-en-19] (confidence: 0.743)
#    Q: What is a popular second language for secondary school students in the UK?
#    A: french or spanish
# --------------------------------------------------------------------------------
#
# ================================================================================
# Locale: zh-CN (Chinese (China))
# ================================================================================
#
# 1. CORRECT [Al-en-01] (confidence: 0.722)
#    Q: 在中国，学龄前儿童常见的零食是什么？
#    A: 巧克力糖果芝士巧克力饼干糖霜饼糖果果冻糖果果冻糖霜饼等 在中国学龄前的儿童常见的零食有巧克力糖果
# --------------------------------------------------------------------------------
# 2. INCORRECT [Al-en-02] (confidence: 0.770)
#    Q: 在中国，有什么受欢迎的食物可以搭配啤酒吃？
#    A: 饺子 jiǎo zi this translate to dumpling in english which be a popular food in china that can be pair with beer
# --------------------------------------------------------------------------------
# 3. CORRECT [Al-en-04] (confidence: 0.631)
#    Q: 在中国最受欢迎的水果是什么？
#    A: 橘子 orange
# --------------------------------------------------------------------------------
# 4. CORRECT [Al-en-06] (confidence: 0.779)
#    Q: 在中国的学校食堂里常见的食物是什么？
#    A: 中国学校食堂里常见的食物有米饭炒饭炒饺子炒蛋豆腐烤鸡烤肉烤鲜果等 简体中文在中国的学校食堂里常见的食物有米饭炒
# --------------------------------------------------------------------------------
# 5. CORRECT [Al-en-08] (confidence: 0.616)
#    Q: 在中国的购物中心里，最常见的零食有哪些？
#    A: 芝士巧克力糖果薯片糖霜糖饼豆腐乳饼干巧克力饼糖饼巧克力奶酪糖饼糖霜等 在中国购物中心
# --------------------------------------------------------------------------------
# 6. INCORRECT [Al-en-09] (confidence: 0.779)
#    Q: 在中国的游乐园里，有什么受欢迎的小吃？
#    A: 在中国的游乐园里受欢迎的小吃有蛋糕糖果烤饼烤肉烤芋头等 translation in chinese amusement park popular snack include cake candy bake bun grill meat and grill taro
# --------------------------------------------------------------------------------
# 7. INCORRECT [Al-en-16] (confidence: 0.845)
#    Q: 在中国，孩子们几岁开始上幼儿园？（只提供阿拉伯数字（例如，12）。）
#    A: 2 岁开始上幼儿园
# --------------------------------------------------------------------------------
# 8. CORRECT [Al-en-17] (confidence: 0.798)
#    Q: 在中国小学，什么课后运动项目比较受欢迎？
#    A: 小学课后运动比较受欢迎的项目包括体育课跳绳乒乓球足球等 translation in chinese primary school popular after-school sport activity include physical education jump rope table tennis and soccer
# --------------------------------------------------------------------------------
# 9. CORRECT [Al-en-18] (confidence: 0.827)
#    Q: 在中国，小学生通常接受哪门学科的私立教育/课外辅导？
#    A: 在中国小学生通常接受数学语文英语等科目的私立教育课外辅导 translation in china small school student usually receive private education tutor for subject like math chinese language and english
# --------------------------------------------------------------------------------
# 10. CORRECT [Al-en-19] (confidence: 0.746)
#    Q: 在中国，高中生普遍学习哪种第二外语？
#    A: english 英语
# --------------------------------------------------------------------------------
#
# ================================================================================
# Locale: am-ET (Amharic (Ethiopia))
# ================================================================================
#
# 1. INCORRECT [Al-en-01] (confidence: 0.860)
#    Q: በኢትዮጵያ ቅድመ መደበኛ ልጆች የተለመደ መክሰስ ምንድን ነው?
#    A: በኢትዮጵያ ቅድመ መደበኛ ልጆች የተለመደ መክሰስ መጠይባያ
# --------------------------------------------------------------------------------
# 2. INCORRECT [Al-en-02] (confidence: 0.752)
#    Q: በኢትዮጵያ ቢራ ጋር ምን ዓይነት ምግብ የተወደደ ነው?
#    A: በኢትዮጵያ ቢራ ጋር መጠይክለው መጠረተው መጠረተው መጠረተው
# --------------------------------------------------------------------------------
# 3. INCORRECT [Al-en-04] (confidence: 0.828)
#    Q: በኢትዮጵያ ምን ዓይነት ፍሬ እጅግ ታዋቂ ነው?
#    A: በኢትዮጵያ መጠይኞች ፍሬ እጅግ ታዋቂ ነው in amharic in ethiopia coffee be traditionally prepare in a clay pot
# --------------------------------------------------------------------------------
# 4. INCORRECT [Al-en-06] (confidence: 0.845)
#    Q: በኢትዮጵያ በትምህርት ቤት መኖሪያ የተለመደ ምግብ ምንድነው?
#    A: በኢትዮጵያ በትምህርት ቤት መኖሪያ የተለመደ ምግብ መጠረሻዊያዊያወይ
# --------------------------------------------------------------------------------
# 5. INCORRECT [Al-en-08] (confidence: 0.834)
#    Q: በኢትዮጵያ በገባያ አዳራሽ ውስጥ በተለይ የሚበሉ ምግቦች ምንናቸው ናቸው?
#    A: በኢትዮጵያ በገባያ በተለይ የሚበሉ ምግቦች በማህበረ በማህበረ በ
# --------------------------------------------------------------------------------
# 6. INCORRECT [Al-en-09] (confidence: 0.888)
#    Q: በኢትዮጵያ የመዝናኛ ፓርክ ውስጥ ታዋቂ አሰራር ምግብ ምንድነው?
#    A: በኢትዮጵያ የመዝናኛ ፓርክ ውስጥ ታዋቂ አሰራር ምግብ መረጃ መረጃ መረ
# --------------------------------------------------------------------------------
# 7. INCORRECT [Al-en-16] (confidence: 0.940)
#    Q: በኢትዮጵያ ልጆች ቅድመ መደበኛ ትምህርት የሚጀምሩበት እድሜ ስንት ነው? (በአረብኛ ቁጥሮች (ምሳሌ 12) ብቻ ይምረጡ።)
#    A: በኢትዮጵያ ልጆች ቅድመ መደበኛ ትምህርት በአረብኛ ቁጥሮች ምሳሌ 12 ብቻ
# --------------------------------------------------------------------------------
# 8. INCORRECT [Al-en-17] (confidence: 0.963)
#    Q: በኢትዮጵያ በመጀመሪያ ደረጃ ትምህርት ቤቶች ከትምህርት በኋላ የሚካሄድ ዝነኛ ስፖርት ዓይነት ምንድነው?
#    A: በኢትዮጵያ በመጀመሪያ ደረጃ ትምህርት ቤቶች ከትምህርት በኋላ የሚካሄድ
# --------------------------------------------------------------------------------
# 9. INCORRECT [Al-en-18] (confidence: 0.791)
#    Q: በኢትዮጵያ በመጀመሪያ ደረጃ ትምህርት ተማሪዎቸ የግል አስጠኚ የሚቀጠርላቸው በተለየ ለየትኛው የትምህርት አይነት ነው?
#    A: መጠውያዊ መሰረ መሰረ መሰረ መሰረ መሰረ መሰረ መ
# --------------------------------------------------------------------------------
# 10. INCORRECT [Al-en-19] (confidence: 0.975)
#    Q: በኢትዮጵያ በሁለተኛ ደረጃ ትምህርት ተማሪዎች ተመራጭ ሁለተኛ ቋንቋ ምንድን ነው?
#    A: በኢትዮጵያ በሁለተኛ ደረጃ ትምህርት ተማሪዎች ተመራጭ ሁለተኛ ቋንቋ
# --------------------------------------------------------------------------------
#
# ================================================================================
# EVALUATION COMPLETE
# ================================================================================

# %% [markdown]
# ## Display SAQ Results Summary
#
# Show accuracy metrics per locale and overall performance.

# %%
# Print SAQ summary
print(f"\n{'='*80}")
print("SAQ EVALUATION SUMMARY")
print(f"{'='*80}\n")

overall_correct = sum(r['correct'] for r in saq_results.values())
overall_total = sum(r['total'] for r in saq_results.values())
overall_accuracy = (overall_correct / overall_total * 100) if overall_total > 0 else 0

print(f"{'Locale':<10} {'Correct':<10} {'Total':<10} {'Accuracy':<10}")
print("-"*80)

for locale in LOCALES.keys():
    correct = saq_results[locale]['correct']
    total = saq_results[locale]['total']
    accuracy = (correct / total * 100) if total > 0 else 0
    print(f"{locale:<10} {correct:<10} {total:<10} {accuracy:>6.1f}%")

print("-"*80)
print(f"{'Overall':<10} {overall_correct:<10} {overall_total:<10} {overall_accuracy:>6.1f}%")
print("="*80)
# Out:
# ================================================================================
# SAQ EVALUATION SUMMARY
# ================================================================================
#
# Locale     Correct    Total      Accuracy
# --------------------------------------------------------------------------------
# en-US      10         10          100.0%
# en-GB      8          10           80.0%
# zh-CN      7          10           70.0%
# am-ET      0          10            0.0%
# --------------------------------------------------------------------------------
# Overall    25         40           62.5%
# ================================================================================

# %% [markdown]
# ## Analyze SAQ Failures
#
# Examine incorrect answers to understand model weaknesses.

# %%
# Show SAQ failure examples
print("\n" + "="*80)
print("FAILURE ANALYSIS")
print("="*80 + "\n")

total_failures = 0

for locale in LOCALES.keys():
    failures = [d for d in saq_results[locale]['details'] if not d['correct']]
    total_failures += len(failures)

    if failures:
        print(f"\n{locale} - {len(failures)} failures:")
        print("-"*80)

        for idx, fail in enumerate(failures, 1):
            print(f"\n{idx}. ID: {fail['question_id']}")
            print(f"   Question: {fail['question']}")
            print(f"   Generated: {fail['generated']}")

            # Show expected answers
            if fail['question_id'] in REFERENCE_ANSWERS[locale]:
                expected = REFERENCE_ANSWERS[locale][fail['question_id']]['annotations']
                expected_list = [a['answers'][0] for a in expected[:3]]
                print(f"   Expected: {', '.join(expected_list)}")

print(f"\n{'='*80}")
print(f"Total failures across all locales: {total_failures}/{overall_total}")
print(f"{'='*80}")
# Out:
# ================================================================================
# FAILURE ANALYSIS
# ================================================================================
#
#
# en-GB - 2 failures:
# --------------------------------------------------------------------------------
#
# 1. ID: Al-en-02
#    Question: What is a popular food to go with beer in the UK?
#    Generated: pie and mash
#    Expected: crisps, nuts, chips
#
# 2. ID: Al-en-06
#    Question: What is a common school cafeteria food in the UK?
#    Generated: pasta jacket potato sausage roll and fish finger be common school cafeteria food in the uk
#    Expected: chips, mash, burger
#
# zh-CN - 3 failures:
# --------------------------------------------------------------------------------
#
# 1. ID: Al-en-02
#    Question: 在中国，有什么受欢迎的食物可以搭配啤酒吃？
#    Generated: 饺子 jiǎo zi this translate to dumpling in english which be a popular food in china that can be pair with beer
#    Expected: 花生米, 炸鸡, 虾干
#
# 2. ID: Al-en-09
#    Question: 在中国的游乐园里，有什么受欢迎的小吃？
#    Generated: 在中国的游乐园里受欢迎的小吃有蛋糕糖果烤饼烤肉烤芋头等 translation in chinese amusement park popular snack include cake candy bake bun grill meat and grill taro
#    Expected: 棉花糖, 雪糕, 轰炸大鱿鱼
#
# 3. ID: Al-en-16
#    Question: 在中国，孩子们几岁开始上幼儿园？（只提供阿拉伯数字（例如，12）。）
#    Generated: 2 岁开始上幼儿园
#    Expected: 3, 4
#
# am-ET - 10 failures:
# --------------------------------------------------------------------------------
#
# 1. ID: Al-en-01
#    Question: በኢትዮጵያ ቅድመ መደበኛ ልጆች የተለመደ መክሰስ ምንድን ነው?
#    Generated: በኢትዮጵያ ቅድመ መደበኛ ልጆች የተለመደ መክሰስ መጠይባያ
#    Expected: ቺፕስ, ዳቦ, ሻይ በዳቦ
#
# 2. ID: Al-en-02
#    Question: በኢትዮጵያ ቢራ ጋር ምን ዓይነት ምግብ የተወደደ ነው?
#    Generated: በኢትዮጵያ ቢራ ጋር መጠይክለው መጠረተው መጠረተው መጠረተው
#    Expected: ቁርጥ, ጥብስ, ጥሬ ስጋ
#
# 3. ID: Al-en-04
#    Question: በኢትዮጵያ ምን ዓይነት ፍሬ እጅግ ታዋቂ ነው?
#    Generated: በኢትዮጵያ መጠይኞች ፍሬ እጅግ ታዋቂ ነው in amharic in ethiopia coffee be traditionally prepare in a clay pot
#    Expected: መንደሪን, ማንጎ
#
# 4. ID: Al-en-06
#    Question: በኢትዮጵያ በትምህርት ቤት መኖሪያ የተለመደ ምግብ ምንድነው?
#    Generated: በኢትዮጵያ በትምህርት ቤት መኖሪያ የተለመደ ምግብ መጠረሻዊያዊያወይ
#    Expected: ብስኩት, ጮርናቄ, እርጥብ
#
# 5. ID: Al-en-08
#    Question: በኢትዮጵያ በገባያ አዳራሽ ውስጥ በተለይ የሚበሉ ምግቦች ምንናቸው ናቸው?
#    Generated: በኢትዮጵያ በገባያ በተለይ የሚበሉ ምግቦች በማህበረ በማህበረ በ
#    Expected: ኩኪስ, አገዳ, ቆሎ
#
# 6. ID: Al-en-09
#    Question: በኢትዮጵያ የመዝናኛ ፓርክ ውስጥ ታዋቂ አሰራር ምግብ ምንድነው?
#    Generated: በኢትዮጵያ የመዝናኛ ፓርክ ውስጥ ታዋቂ አሰራር ምግብ መረጃ መረጃ መረ
#    Expected: ኬክ, በርገር, እርጥብ
#
# 7. ID: Al-en-16
#    Question: በኢትዮጵያ ልጆች ቅድመ መደበኛ ትምህርት የሚጀምሩበት እድሜ ስንት ነው? (በአረብኛ ቁጥሮች (ምሳሌ 12) ብቻ ይምረጡ።)
#    Generated: በኢትዮጵያ ልጆች ቅድመ መደበኛ ትምህርት በአረብኛ ቁጥሮች ምሳሌ 12 ብቻ
#    Expected: 3, 4
#
# 8. ID: Al-en-17
#    Question: በኢትዮጵያ በመጀመሪያ ደረጃ ትምህርት ቤቶች ከትምህርት በኋላ የሚካሄድ ዝነኛ ስፖርት ዓይነት ምንድነው?
#    Generated: በኢትዮጵያ በመጀመሪያ ደረጃ ትምህርት ቤቶች ከትምህርት በኋላ የሚካሄድ
#    Expected: እግር ኳስ, መረብ ኳስ, ሩጫ
#
# 9. ID: Al-en-18
#    Question: በኢትዮጵያ በመጀመሪያ ደረጃ ትምህርት ተማሪዎቸ የግል አስጠኚ የሚቀጠርላቸው በተለየ ለየትኛው የትምህርት አይነት ነው?
#    Generated: መጠውያዊ መሰረ መሰረ መሰረ መሰረ መሰረ መሰረ መ
#    Expected: ለሂሳብ, ለእንግሊዝኛ
#
# 10. ID: Al-en-19
#    Question: በኢትዮጵያ በሁለተኛ ደረጃ ትምህርት ተማሪዎች ተመራጭ ሁለተኛ ቋንቋ ምንድን ነው?
#    Generated: በኢትዮጵያ በሁለተኛ ደረጃ ትምህርት ተማሪዎች ተመራጭ ሁለተኛ ቋንቋ
#    Expected: እንግሊዝኛ
#
# ================================================================================
# Total failures across all locales: 15/40
# ================================================================================

# %% [markdown]
# ## SAQ Confidence Analysis
#
# Analyze confidence scores and abstention behavior to understand model uncertainty.

# %%
# Confidence Analysis for SAQ
print("\n" + "="*80)
print("CONFIDENCE ANALYSIS (SAQ)")
print("="*80 + "\n")

for locale in LOCALES.keys():
    details = saq_results[locale]['details']

    # Calculate metrics
    confidences = [d.get('confidence', 0.0) for d in details]
    correct_confidences = [d.get('confidence', 0.0) for d in details if d['correct']]
    incorrect_confidences = [d.get('confidence', 0.0) for d in details if not d['correct']]

    print(f"\n{locale} ({LOCALES[locale]['name']}):")
    print("-"*80)
    print(f"  Avg confidence (all): {np.mean(confidences):.3f}")
    if correct_confidences:
        print(f"  Avg confidence (correct): {np.mean(correct_confidences):.3f}")
    if incorrect_confidences:
        print(f"  Avg confidence (incorrect): {np.mean(incorrect_confidences):.3f}")

    # Abstention metrics
    abstained_count = sum(1 for d in details if d.get('abstained', False))
    answered_count = len(details) - abstained_count
    answered_correct = sum(1 for d in details if d['correct'] and not d.get('abstained', False))

    print(f"\n  Abstained: {abstained_count}/{len(details)} ({abstained_count/len(details)*100:.1f}%)")
    print(f"  Coverage (answered): {answered_count}/{len(details)} ({answered_count/len(details)*100:.1f}%)")
    if answered_count > 0:
        precision = answered_correct / answered_count * 100
        print(f"  Precision (on answered): {answered_correct}/{answered_count} ({precision:.1f}%)")
    else:
        print(f"  Precision (on answered): N/A (no questions answered)")

# Overall confidence statistics
all_confidences = []
all_correct_confidences = []
all_incorrect_confidences = []

for locale in LOCALES.keys():
    for d in saq_results[locale]['details']:
        conf = d.get('confidence', 0.0)
        all_confidences.append(conf)
        if d['correct']:
            all_correct_confidences.append(conf)
        else:
            all_incorrect_confidences.append(conf)

print(f"\n{'='*80}")
print("OVERALL CONFIDENCE STATISTICS")
print(f"{'='*80}")
print(f"Average confidence (all): {np.mean(all_confidences):.3f}")
print(f"Average confidence (correct): {np.mean(all_correct_confidences):.3f}")
print(f"Average confidence (incorrect): {np.mean(all_incorrect_confidences):.3f}")
print(f"Confidence gap (correct - incorrect): {np.mean(all_correct_confidences) - np.mean(all_incorrect_confidences):.3f}")
print(f"{'='*80}")
# Out:
# ================================================================================
# CONFIDENCE ANALYSIS (SAQ)
# ================================================================================
#
#
# en-US (English (United States)):
# --------------------------------------------------------------------------------
#   Avg confidence (all): 0.836
#   Avg confidence (correct): 0.836
#
#   Abstained: 0/10 (0.0%)
#   Coverage (answered): 10/10 (100.0%)
#   Precision (on answered): 10/10 (100.0%)
#
# en-GB (English (United Kingdom)):
# --------------------------------------------------------------------------------
#   Avg confidence (all): 0.805
#   Avg confidence (correct): 0.809
#   Avg confidence (incorrect): 0.790
#
#   Abstained: 0/10 (0.0%)
#   Coverage (answered): 10/10 (100.0%)
#   Precision (on answered): 8/10 (80.0%)
#
# zh-CN (Chinese (China)):
# --------------------------------------------------------------------------------
#   Avg confidence (all): 0.751
#   Avg confidence (correct): 0.731
#   Avg confidence (incorrect): 0.798
#
#   Abstained: 0/10 (0.0%)
#   Coverage (answered): 10/10 (100.0%)
#   Precision (on answered): 7/10 (70.0%)
#
# am-ET (Amharic (Ethiopia)):
# --------------------------------------------------------------------------------
#   Avg confidence (all): 0.868
#   Avg confidence (incorrect): 0.868
#
#   Abstained: 0/10 (0.0%)
#   Coverage (answered): 10/10 (100.0%)
#   Precision (on answered): 0/10 (0.0%)
#
# ================================================================================
# OVERALL CONFIDENCE STATISTICS
# ================================================================================
# Average confidence (all): 0.815
# Average confidence (correct): 0.798
# Average confidence (incorrect): 0.843
# Confidence gap (correct - incorrect): -0.045
# ================================================================================

# %% [markdown]
# ## Baseline MCQ System
# ### Track B: Multiple Choice Questions (MCQ)
# Direct prompting baseline for multiple choice questions with choice extraction.

# %%
class BaselineMCQSystem(BaseQuestionSystem):
    """Baseline Multiple Choice Question system using direct prompting."""

    def __init__(self, model, tokenizer, temperature=0.0):
        super().__init__(model, tokenizer, temperature, max_new_tokens=50)

    def create_prompt(self, csv_prompt: str, locale: str) -> str:
        """Use the prompt from CSV file (already formatted with JSON requirement), along with a persona based on the locale """

        # locale_config = LOCALES.get(locale)

        # Define persona based on locale
        personas = {
            'en-US': "You are an American cultural expert with deep knowledge of US everyday life, food, traditions, and customs. You answer simply and directly, with no explanation just the simple,direct answer.",
            'en-GB': "You are a British cultural expert with deep knowledge of UK everyday life, food, traditions, and customs. You answer simply and directly, with no explanation, with no explanation just the simple,direct answer.",
            'zh-CN': "You are a Chinese cultural expert with deep knowledge of Chinese everyday life, food, traditions, and customs. You answer simply and directly, with no explanation, with no explanation just the simple,direct answer.",
            'am-ET': "You are an Ethiopian cultural expert with deep knowledge of Ethiopian everyday life, food, traditions, and customs. You answer simply and directly, with no explanation, with no explanation just the simple,direct answer."
        }

        persona = personas.get(locale, "You are a cultural expert. You answer simply and directly, with no explanation just the simple,direct answer.")

        # The CSV prompt already contains the question, choices, and JSON format instruction
        # We can just wrap it in the appropriate model format, along with the persona

        if "TinyLlama" in MODEL_NAME:
            prompt = f"""<|system|>
                {persona}.</s>
                <|user|>
                {csv_prompt}</s>
                <|assistant|>
                """
        else:
            # Mistral format
            prompt = f"""[INST] {persona} : {csv_prompt} [/INST]"""

        return prompt

    def extract_choice(self, response: str) -> Optional[str]:
        """Extract choice letter from JSON response format: {\"answer_choice\":\"A\"}."""
        if not response:
            return None

        # Try to parse as JSON first
        try:
            # Find JSON object in response
            json_match = re.search(r'\{[^}]*"answer_choice"[^}]*\}', response)
            if json_match:
                json_str = json_match.group(0)
                data = json.loads(json_str)
                choice = data.get('answer_choice', '').strip().upper()
                if choice and choice[0] in 'ABCD':
                    return choice[0]
        except (json.JSONDecodeError, KeyError):
            pass

        # Fallback: Try to find first occurrence of A, B, C, or D
        match = re.search(r'\b([A-D])\b', response)
        if match:
            return match.group(1)

        # Last resort: check if response starts with a letter
        response = response.strip().upper()
        if response and response[0] in 'ABCD':
            return response[0]

        return None

    def generate_answer(self, csv_prompt: str, choices: Dict[str, str],
                       locale: str, country: str, return_confidence: bool = True) -> Dict:
        """Generate answer for MCQ using CSV prompt."""
        # Create prompt from CSV (which already contains question and format instructions)
        prompt = self.create_prompt(csv_prompt, locale)

        # Generate response with confidence
        if return_confidence:
            raw_response, confidence = self.generate_response(prompt, return_confidence=True)
        else:
            raw_response = self.generate_response(prompt, return_confidence=False)
            confidence = None

        # Extract choice
        predicted_choice = self.extract_choice(raw_response)

        result = {
            'csv_prompt': csv_prompt,
            'choices': choices,
            'locale': locale,
            'country': country,
            'predicted_choice': predicted_choice,
            'raw_response': raw_response,
            'prompt': prompt
        }

        if confidence is not None:
            result['confidence'] = confidence

        return result

    def evaluate_answer(self, predicted_choice: str, correct_answer: str) -> bool:
        """Evaluate if predicted choice matches correct answer."""
        if not predicted_choice:
            return False
        return predicted_choice.upper() == correct_answer.upper()

# Initialize MCQ system
mcq_system = BaselineMCQSystem(
    model=model,
    tokenizer=tokenizer,
    temperature=TEMPERATURE
)

print("✓ Baseline MCQ System initialized")
print(f"  Model: {MODEL_NAME}")
print(f"  Temperature: {TEMPERATURE}")
print(f"  Max new tokens: {mcq_system.max_new_tokens}")
# Out:
# ✓ Baseline MCQ System initialized
#   Model: mistralai/Mistral-7B-Instruct-v0.3
#   Temperature: 0.0
#   Max new tokens: 50

# %% [markdown]
# ## Load MCQ Data
#
# Load multiple choice questions from CSV file with JSON parsing.

# %%
def load_mcq_data(csv_path: str, num_questions: Optional[int] = None) -> pd.DataFrame:
    """Load MCQ data from CSV."""
    df = pd.read_csv(csv_path)

    # Parse JSON columns
    df['choices'] = df['choices'].apply(json.loads)
    df['choice_countries'] = df['choice_countries'].apply(json.loads)

    if num_questions:
        df = df.head(num_questions)

    return df

# Load MCQ data
if IN_COLAB:
    num_questions=10000
else:
    num_questions=20
mcq_df = load_mcq_data(f'{DATA_FILES_PATH}/mcq_questions/mc_questions_file-1.csv', num_questions)

print(f"✓ Loaded {len(mcq_df)} MCQ questions")
# Out:
# ✓ Loaded 10000 MCQ questions

# %% [markdown]
# ## Evaluate MCQ System
#
# Run evaluation on MCQ dataset and calculate accuracy.

# %%
def evaluate_mcq_system(system, df, locale='en-GB'):
    """Evaluate MCQ system on a BLEND dataset."""
    results = []
    correct = 0
    total = 0

    print(f"Evaluating MCQ System on {len(df)} questions...\n")
    print("="*80)

    for idx, row in df.iterrows():
        # Generate answer with confidence
        result = system.generate_answer(
            csv_prompt=row['prompt'],
            choices=row['choices'],
            locale=locale,
            country=row['country'],
            return_confidence=True
        )

        confidence = result.get('confidence', 0.0)

        # Optional: Implement abstention for MCQ
        CONFIDENCE_THRESHOLD = 0.3
        abstained = system.should_abstain(confidence, CONFIDENCE_THRESHOLD)

        if abstained:
            result['predicted_choice'] = None
            result['abstained'] = True
        else:
            result['abstained'] = False

        # Evaluate
        is_correct = system.evaluate_answer(
            result['predicted_choice'],
            row['answer_idx']
        )

        result['correct_answer'] = row['answer_idx']
        result['is_correct'] = is_correct
        result['mcqid'] = row['MCQID']
        result['id'] = row['ID']

        results.append(result)

        if is_correct:
            correct += 1
        total += 1

        # Print progress with confidence
        status = "CORRECT" if is_correct else "INCORRECT"
        abstain_marker = " [ABSTAINED]" if abstained else ""
        print(f"{idx+1}. {status}{abstain_marker} [{row['MCQID']}] (confidence: {confidence:.3f})")
        print(f" Answer given   : {result['predicted_choice']}")
        print(f" Correct answer : {row['answer_idx']}")
        print(f" Raw response   : [{result['raw_response']}]")
        print("-"*80)

    accuracy = correct / total if total > 0 else 0

    print("\n" + "="*80)
    print(f"MCQ EVALUATION RESULTS")
    print("="*80)
    print(f"Accuracy: {accuracy:.2%} ({correct}/{total})")
    print("="*80)

    return results, accuracy

# Evaluate MCQ across all locales
mcq_results_by_locale = {}
mcq_accuracy_by_locale = {}

# Map locales to country names in the dataset
locale_to_country = {
    'en-US': 'US',
    'en-GB': 'UK',
    'zh-CN': 'China',
    'am-ET': 'Ethiopia'
}

print("="*80)
print("EVALUATING MCQ SYSTEM ACROSS ALL LOCALES")
print("="*80)

for locale_code, country_name in locale_to_country.items():
    print(f"\n{'='*80}")
    print(f"LOCALE: {locale_code} ({LOCALES[locale_code]['name']}) - Country: {country_name}")
    print(f"{'='*80}\n")

    # Filter MCQ data for this country
    locale_df = mcq_df[mcq_df['country'] == country_name].copy()

    if len(locale_df) == 0:
        print(f"⚠️ No questions found for {country_name}")
        continue

    print(f"Testing {len(locale_df)} questions for {country_name}...\n")

    # Evaluate on this locale
    results, accuracy = evaluate_mcq_system(mcq_system, locale_df, locale=locale_code)

    # Store results
    mcq_results_by_locale[locale_code] = results
    mcq_accuracy_by_locale[locale_code] = accuracy

# Print summary table
print("\n" + "="*80)
print("MCQ EVALUATION SUMMARY - ALL LOCALES")
print("="*80)
print(f"{'Locale':<15} {'Country':<15} {'Correct':<10} {'Total':<10} {'Accuracy':<10}")
print("-"*80)

overall_correct = 0
overall_total = 0

for locale_code, country_name in locale_to_country.items():
    if locale_code in mcq_results_by_locale:
        results = mcq_results_by_locale[locale_code]
        correct = sum(1 for r in results if r['is_correct'])
        total = len(results)
        accuracy = mcq_accuracy_by_locale[locale_code]

        overall_correct += correct
        overall_total += total

        print(f"{locale_code:<15} {country_name:<15} {correct:<10} {total:<10} {accuracy:>6.1%}")

print("-"*80)
overall_accuracy = overall_correct / overall_total if overall_total > 0 else 0
print(f"{'Overall':<15} {'All':<15} {overall_correct:<10} {overall_total:<10} {overall_accuracy:>6.1%}")
print("="*80)

# Calculate performance gap
if mcq_accuracy_by_locale:
    best_accuracy = max(mcq_accuracy_by_locale.values())
    print(f"\nBest performing locale: {best_accuracy:.1%}")
    print("\nPerformance gaps from best:")
    for locale_code in LOCALES.keys():
        if locale_code in mcq_accuracy_by_locale:
            gap = best_accuracy - mcq_accuracy_by_locale[locale_code]
            print(f"  {locale_code}: {gap:+.1%}")
# Out:
# Streaming output truncated to the last 5000 lines.
# --------------------------------------------------------------------------------
# 7180. CORRECT [Ji-ko-03_5083] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7181. CORRECT [Ji-ko-03_5084] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7182. CORRECT [Ji-ko-03_5085] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7183. CORRECT [Ji-ko-03_5086] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7184. CORRECT [Ji-ko-03_5087] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7185. CORRECT [Ji-ko-03_5088] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7186. CORRECT [Ji-ko-03_5089] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7187. CORRECT [Ji-ko-03_5090] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7188. CORRECT [Ji-ko-03_5091] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7189. CORRECT [Ji-ko-03_5092] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7190. CORRECT [Ji-ko-03_5093] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7191. CORRECT [Ji-ko-03_5094] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7192. CORRECT [Ji-ko-03_5095] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7193. CORRECT [Ji-ko-03_5096] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7194. CORRECT [Ji-ko-03_5097] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7195. CORRECT [Ji-ko-03_5098] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7196. CORRECT [Ji-ko-03_5099] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7197. CORRECT [Ji-ko-03_5100] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7198. CORRECT [Ji-ko-03_5101] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7199. CORRECT [Ji-ko-03_5102] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7200. CORRECT [Ji-ko-03_5103] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7201. CORRECT [Ji-ko-03_5104] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7202. CORRECT [Ji-ko-03_5105] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7203. CORRECT [Ji-ko-03_5106] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7204. CORRECT [Ji-ko-03_5107] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7205. CORRECT [Ji-ko-03_5108] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7206. CORRECT [Ji-ko-03_5109] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7207. CORRECT [Ji-ko-03_5110] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7208. CORRECT [Ji-ko-03_5111] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7209. CORRECT [Ji-ko-03_5112] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7210. CORRECT [Ji-ko-03_5113] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7211. CORRECT [Ji-ko-03_5114] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7212. CORRECT [Ji-ko-03_5115] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7213. CORRECT [Ji-ko-03_5116] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7214. CORRECT [Ji-ko-03_5117] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7215. CORRECT [Ji-ko-03_5118] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7216. CORRECT [Ji-ko-03_5119] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7217. CORRECT [Ji-ko-03_5120] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7218. CORRECT [Ji-ko-03_5121] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7219. CORRECT [Ji-ko-03_5122] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7220. CORRECT [Ji-ko-03_5123] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7221. CORRECT [Ji-ko-03_5124] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7222. CORRECT [Ji-ko-03_5125] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7223. CORRECT [Ji-ko-03_5126] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7224. CORRECT [Ji-ko-03_5127] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7225. CORRECT [Ji-ko-03_5128] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7226. CORRECT [Ji-ko-03_5129] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7227. CORRECT [Ji-ko-03_5130] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7228. CORRECT [Ji-ko-03_5131] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7229. CORRECT [Ji-ko-03_5132] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7230. CORRECT [Ji-ko-03_5133] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7231. CORRECT [Ji-ko-03_5134] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7232. CORRECT [Ji-ko-03_5135] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7233. CORRECT [Ji-ko-03_5136] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7234. CORRECT [Ji-ko-03_5137] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7235. CORRECT [Ji-ko-03_5138] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7236. CORRECT [Ji-ko-03_5139] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7237. CORRECT [Ji-ko-03_5140] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7238. CORRECT [Ji-ko-03_5141] (confidence: 0.970)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7239. CORRECT [Ji-ko-03_5142] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7240. CORRECT [Ji-ko-03_5143] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7241. CORRECT [Ji-ko-03_5144] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7242. CORRECT [Ji-ko-03_5145] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7243. CORRECT [Ji-ko-03_5146] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7244. CORRECT [Ji-ko-03_5147] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7245. CORRECT [Ji-ko-03_5148] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7246. CORRECT [Ji-ko-03_5149] (confidence: 0.958)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7247. CORRECT [Ji-ko-03_5150] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7248. CORRECT [Ji-ko-03_5151] (confidence: 0.959)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7249. CORRECT [Ji-ko-03_5152] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7250. CORRECT [Ji-ko-03_5153] (confidence: 0.961)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7251. CORRECT [Ji-ko-03_5154] (confidence: 0.961)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7252. CORRECT [Ji-ko-03_5155] (confidence: 0.961)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7253. CORRECT [Ji-ko-03_5156] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7254. CORRECT [Ji-ko-03_5157] (confidence: 0.960)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7255. CORRECT [Ji-ko-03_5158] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7256. CORRECT [Ji-ko-03_5159] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7257. CORRECT [Ji-ko-03_5160] (confidence: 0.959)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7258. CORRECT [Ji-ko-03_5161] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7259. CORRECT [Ji-ko-03_5162] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7260. CORRECT [Ji-ko-03_5163] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7261. CORRECT [Ji-ko-03_5164] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7262. CORRECT [Ji-ko-03_5165] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7263. CORRECT [Ji-ko-03_5166] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7264. CORRECT [Ji-ko-03_5167] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7265. CORRECT [Ji-ko-03_5168] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7266. CORRECT [Ji-ko-03_5169] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7267. CORRECT [Ji-ko-03_5170] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7268. CORRECT [Ji-ko-03_5171] (confidence: 0.971)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7269. CORRECT [Ji-ko-03_5172] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7270. CORRECT [Ji-ko-03_5173] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7271. CORRECT [Ji-ko-03_5174] (confidence: 0.971)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7272. CORRECT [Ji-ko-03_5175] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7273. CORRECT [Ji-ko-03_5176] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7274. CORRECT [Ji-ko-03_5177] (confidence: 0.958)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7275. CORRECT [Ji-ko-03_5178] (confidence: 0.959)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7276. CORRECT [Ji-ko-03_5179] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7277. CORRECT [Ji-ko-03_5180] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7278. CORRECT [Ji-ko-03_5181] (confidence: 0.958)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7279. CORRECT [Ji-ko-03_5182] (confidence: 0.959)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7280. CORRECT [Ji-ko-03_5183] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7281. CORRECT [Ji-ko-03_5184] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7282. CORRECT [Ji-ko-03_5185] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7283. CORRECT [Ji-ko-03_5186] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7284. CORRECT [Ji-ko-03_5187] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7285. CORRECT [Ji-ko-03_5188] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7286. CORRECT [Ji-ko-03_5189] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7287. CORRECT [Ji-ko-03_5190] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7288. CORRECT [Ji-ko-03_5191] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7289. CORRECT [Ji-ko-03_5192] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7290. CORRECT [Ji-ko-03_5193] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7291. CORRECT [Ji-ko-03_5194] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7292. CORRECT [Ji-ko-03_5195] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7293. CORRECT [Ji-ko-03_5196] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7294. CORRECT [Ji-ko-03_5197] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7295. CORRECT [Ji-ko-03_5198] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7296. CORRECT [Ji-ko-03_5199] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7297. CORRECT [Ji-ko-03_5200] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7298. CORRECT [Ji-ko-03_5201] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7299. CORRECT [Ji-ko-03_5202] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7300. CORRECT [Ji-ko-03_5203] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7301. CORRECT [Ji-ko-03_5204] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7302. CORRECT [Ji-ko-03_5205] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7303. CORRECT [Ji-ko-03_5206] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7304. CORRECT [Ji-ko-03_5207] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7305. CORRECT [Ji-ko-03_5208] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7306. CORRECT [Ji-ko-03_5209] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7307. CORRECT [Ji-ko-03_5210] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7308. CORRECT [Ji-ko-03_5211] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7309. CORRECT [Ji-ko-03_5212] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7310. CORRECT [Ji-ko-03_5213] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7311. CORRECT [Ji-ko-03_5214] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7312. CORRECT [Ji-ko-03_5215] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7313. CORRECT [Ji-ko-03_5216] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7314. CORRECT [Ji-ko-03_5217] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7315. CORRECT [Ji-ko-03_5218] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7316. CORRECT [Ji-ko-03_5219] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7317. CORRECT [Ji-ko-03_5220] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7318. CORRECT [Ji-ko-03_5221] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7319. CORRECT [Ji-ko-03_5222] (confidence: 0.958)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7320. CORRECT [Ji-ko-03_5223] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7321. CORRECT [Ji-ko-03_5224] (confidence: 0.961)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7322. CORRECT [Ji-ko-03_5225] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7323. CORRECT [Ji-ko-03_5226] (confidence: 0.958)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7324. CORRECT [Ji-ko-03_5227] (confidence: 0.959)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7325. CORRECT [Ji-ko-03_5228] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7326. CORRECT [Ji-ko-03_5229] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7327. CORRECT [Ji-ko-03_5230] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7328. CORRECT [Ji-ko-03_5231] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7329. CORRECT [Ji-ko-03_5232] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7330. CORRECT [Ji-ko-03_5233] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7331. CORRECT [Ji-ko-03_5234] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7332. CORRECT [Ji-ko-03_5235] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7333. CORRECT [Ji-ko-03_5236] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7334. CORRECT [Ji-ko-03_5237] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7335. CORRECT [Ji-ko-03_5238] (confidence: 0.961)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7336. CORRECT [Ji-ko-03_5239] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7337. CORRECT [Ji-ko-03_5240] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7338. CORRECT [Ji-ko-03_5241] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7339. CORRECT [Ji-ko-03_5242] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7340. CORRECT [Ji-ko-03_5243] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7341. CORRECT [Ji-ko-03_5244] (confidence: 0.961)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7342. CORRECT [Ji-ko-03_5245] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7343. CORRECT [Ji-ko-03_5246] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7344. CORRECT [Ji-ko-03_5247] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7345. CORRECT [Ji-ko-03_5248] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7346. CORRECT [Ji-ko-03_5249] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7347. CORRECT [Ji-ko-03_5250] (confidence: 0.970)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7348. CORRECT [Ji-ko-03_5251] (confidence: 0.971)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7349. CORRECT [Ji-ko-03_5252] (confidence: 0.974)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7350. CORRECT [Ji-ko-03_5253] (confidence: 0.973)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7351. CORRECT [Ji-ko-03_5254] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7352. CORRECT [Ji-ko-03_5255] (confidence: 0.973)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7353. CORRECT [Ji-ko-03_5256] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7354. CORRECT [Ji-ko-03_5257] (confidence: 0.958)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7355. CORRECT [Ji-ko-03_5258] (confidence: 0.961)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7356. CORRECT [Ji-ko-03_5259] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7357. CORRECT [Ji-ko-03_5260] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7358. CORRECT [Ji-ko-03_5261] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7359. CORRECT [Ji-ko-03_5262] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7360. CORRECT [Ji-ko-03_5263] (confidence: 0.959)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7361. CORRECT [Ji-ko-03_5264] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7362. CORRECT [Ji-ko-03_5265] (confidence: 0.970)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7363. CORRECT [Ji-ko-03_5266] (confidence: 0.970)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7364. CORRECT [Ji-ko-03_5267] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7365. CORRECT [Ji-ko-03_5268] (confidence: 0.970)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7366. CORRECT [Ji-ko-03_5269] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7367. CORRECT [Ji-ko-03_5270] (confidence: 0.970)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7368. CORRECT [Ji-ko-03_5271] (confidence: 0.966)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7369. CORRECT [Ji-ko-03_5272] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7370. CORRECT [Ji-ko-03_5273] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7371. CORRECT [Ji-ko-03_5274] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7372. CORRECT [Ji-ko-03_5275] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7373. CORRECT [Ji-ko-03_5276] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7374. CORRECT [Ji-ko-03_5277] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7375. CORRECT [Ji-ko-03_5278] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7376. CORRECT [Ji-ko-03_5279] (confidence: 0.971)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7377. CORRECT [Ji-ko-03_5280] (confidence: 0.970)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7378. CORRECT [Ji-ko-03_5281] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7379. CORRECT [Ji-ko-03_5282] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7380. CORRECT [Ji-ko-03_5283] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7381. CORRECT [Ji-ko-03_5284] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7382. CORRECT [Ji-ko-03_5285] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7383. CORRECT [Ji-ko-03_5286] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7384. CORRECT [Ji-ko-03_5287] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7385. CORRECT [Ji-ko-03_5288] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7386. CORRECT [Ji-ko-03_5289] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7387. CORRECT [Ji-ko-03_5290] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7388. CORRECT [Ji-ko-03_5291] (confidence: 0.962)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7389. CORRECT [Ji-ko-03_5292] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7390. CORRECT [Ji-ko-03_5293] (confidence: 0.970)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7391. CORRECT [Ji-ko-03_5294] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7392. CORRECT [Ji-ko-03_5295] (confidence: 0.971)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7393. CORRECT [Ji-ko-03_5296] (confidence: 0.973)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7394. CORRECT [Ji-ko-03_5297] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7395. CORRECT [Ji-ko-03_5298] (confidence: 0.974)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7396. CORRECT [Ji-ko-03_5299] (confidence: 0.973)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7397. CORRECT [Ji-ko-03_5300] (confidence: 0.965)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7398. CORRECT [Ji-ko-03_5301] (confidence: 0.973)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7399. CORRECT [Ji-ko-03_5302] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7400. CORRECT [Ji-ko-03_5303] (confidence: 0.974)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7401. CORRECT [Ji-ko-03_5304] (confidence: 0.969)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7402. CORRECT [Ji-ko-03_5305] (confidence: 0.973)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 7403. CORRECT [Ji-ko-03_5306] (confidence: 0.968)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# ...
# --------------------------------------------------------------------------------
# 9469. INCORRECT [Jod-ch-04_753] (confidence: 0.988)
#  Answer given   : B
#  Correct answer : D
#  Raw response   : [{"answer_choice": "B"}]
# --------------------------------------------------------------------------------
# 9470. INCORRECT [Jod-ch-04_754] (confidence: 0.985)
#  Answer given   : B
#  Correct answer : D
#  Raw response   : [{"answer_choice": "B"}]
# --------------------------------------------------------------------------------
# 9471. INCORRECT [Jod-ch-04_755] (confidence: 0.981)
#  Answer given   : B
#  Correct answer : C
#  Raw response   : [{"answer_choice": "B"}]
# --------------------------------------------------------------------------------
# 9472. INCORRECT [Jod-ch-04_756] (confidence: 0.986)
#  Answer given   : B
#  Correct answer : C
#  Raw response   : [{"answer_choice": "B"}]
# --------------------------------------------------------------------------------
# 9473. INCORRECT [Jod-ch-04_757] (confidence: 0.983)
#  Answer given   : B
#  Correct answer : C
#  Raw response   : [{"answer_choice": "B"}]
# --------------------------------------------------------------------------------
# 9474. INCORRECT [Jod-ch-04_758] (confidence: 0.979)
#  Answer given   : C
#  Correct answer : D
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9534. CORRECT [Jod-ch-06_229] (confidence: 0.959)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9535. CORRECT [Jod-ch-06_230] (confidence: 0.967)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9536. CORRECT [Jod-ch-06_231] (confidence: 0.964)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9537. INCORRECT [Jod-ch-06_232] (confidence: 0.959)
#  Answer given   : C
#  Correct answer : A
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9538. CORRECT [Jod-ch-06_233] (confidence: 0.953)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9539. CORRECT [Jod-ch-06_234] (confidence: 0.952)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9540. CORRECT [Jod-ch-06_235] (confidence: 0.936)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9541. CORRECT [Jod-ch-06_237] (confidence: 0.952)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9542. CORRECT [Jod-ch-06_238] (confidence: 0.947)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9543. CORRECT [Jod-ch-06_239] (confidence: 0.952)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9544. CORRECT [Jod-ch-06_240] (confidence: 0.940)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9545. INCORRECT [Jod-ch-06_241] (confidence: 0.938)
#  Answer given   : C
#  Correct answer : A
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9546. CORRECT [Jod-ch-06_242] (confidence: 0.963)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9547. INCORRECT [Jod-ch-06_243] (confidence: 0.935)
#  Answer given   : C
#  Correct answer : A
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9548. INCORRECT [Jod-ch-06_244] (confidence: 0.950)
#  Answer given   : C
#  Correct answer : A
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9549. CORRECT [Jod-ch-06_245] (confidence: 0.942)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9550. CORRECT [Jod-ch-06_246] (confidence: 0.923)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9551. CORRECT [Jod-ch-06_247] (confidence: 0.872)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9552. CORRECT [Jod-ch-06_248] (confidence: 0.932)
#  Answer given   : A
#  Correct answer : A
#  Raw response   : [{"answer_choice": "A"}]
# --------------------------------------------------------------------------------
# 9602. INCORRECT [Jod-ch-09_195] (confidence: 0.974)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9603. INCORRECT [Jod-ch-09_196] (confidence: 0.950)
#  Answer given   : C
#  Correct answer : D
#  Raw response   : [{"answer_choice": "C. 19:00"}]
# --------------------------------------------------------------------------------
# 9604. INCORRECT [Jod-ch-09_197] (confidence: 0.953)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9605. INCORRECT [Jod-ch-09_198] (confidence: 0.970)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9606. INCORRECT [Jod-ch-09_199] (confidence: 0.974)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9607. INCORRECT [Jod-ch-09_200] (confidence: 0.945)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "20:00"}]
# --------------------------------------------------------------------------------
# 9608. INCORRECT [Jod-ch-09_201] (confidence: 0.905)
#  Answer given   : C
#  Correct answer : D
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9609. INCORRECT [Jod-ch-09_202] (confidence: 0.838)
#  Answer given   : B
#  Correct answer : C
#  Raw response   : [{"answer_choice": "B", "explanation": "In Ethiopia, dinner is typically served around 19:00."}]
# --------------------------------------------------------------------------------
# 9610. INCORRECT [Jod-ch-09_203] (confidence: 0.973)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9611. INCORRECT [Jod-ch-09_204] (confidence: 0.787)
#  Answer given   : B
#  Correct answer : C
#  Raw response   : [{"answer_choice": "B", "explanation": "In Ethiopia, dinner is traditionally served around 19:00 (7 PM local time). However, this can vary depending on individual and family preferences."}]
# --------------------------------------------------------------------------------
# 9612. INCORRECT [Jod-ch-09_205] (confidence: 0.945)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9613. INCORRECT [Jod-ch-09_206] (confidence: 0.952)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "20:00"}]
# --------------------------------------------------------------------------------
# 9614. INCORRECT [Jod-ch-09_207] (confidence: 0.962)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9615. INCORRECT [Jod-ch-09_208] (confidence: 0.982)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9616. INCORRECT [Jod-ch-09_209] (confidence: 0.952)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9617. INCORRECT [Jod-ch-09_210] (confidence: 0.966)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9618. INCORRECT [Jod-ch-09_211] (confidence: 0.977)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "20:00"}]
# --------------------------------------------------------------------------------
# 9619. INCORRECT [Jod-ch-09_212] (confidence: 0.965)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "18:30"}]
# --------------------------------------------------------------------------------
# 9620. CORRECT [Jod-ch-09_213] (confidence: 0.927)
#  Answer given   : C
#  Correct answer : C
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9621. INCORRECT [Jod-ch-09_214] (confidence: 0.953)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "20:00"}]
# --------------------------------------------------------------------------------
# 9622. INCORRECT [Jod-ch-09_215] (confidence: 0.965)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9623. INCORRECT [Jod-ch-09_216] (confidence: 0.960)
#  Answer given   : C
#  Correct answer : D
#  Raw response   : [{"answer_choice": "C. 19:00"}]
# --------------------------------------------------------------------------------
# 9624. INCORRECT [Jod-ch-09_217] (confidence: 0.971)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9625. INCORRECT [Jod-ch-09_218] (confidence: 0.976)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9626. INCORRECT [Jod-ch-09_219] (confidence: 0.969)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9627. INCORRECT [Jod-ch-09_220] (confidence: 0.968)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "20:30"}]
# --------------------------------------------------------------------------------
# 9628. INCORRECT [Jod-ch-09_221] (confidence: 0.932)
#  Answer given   : C
#  Correct answer : D
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9629. INCORRECT [Jod-ch-09_222] (confidence: 0.836)
#  Answer given   : B
#  Correct answer : C
#  Raw response   : [{"answer_choice": "B", "explanation": "In Ethiopia, dinner is typically served around 19:00."}]
# --------------------------------------------------------------------------------
# 9630. INCORRECT [Jod-ch-09_223] (confidence: 0.977)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "19:00"}]
# --------------------------------------------------------------------------------
# 9631. INCORRECT [Jod-ch-09_224] (confidence: 0.766)
#  Answer given   : B
#  Correct answer : C
#  Raw response   : [{"answer_choice": "B", "explanation": "In Ethiopia, dinner is typically served around 19:00 (7 PM local time). This is due to the Ethiopian calendar, which is 7]
# --------------------------------------------------------------------------------
# 9632. INCORRECT [Jod-ch-09_225] (confidence: 0.948)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "18:30"}]
# --------------------------------------------------------------------------------
# 9633. INCORRECT [Jod-ch-09_227] (confidence: 0.941)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9634. INCORRECT [Jod-ch-09_228] (confidence: 0.979)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9635. INCORRECT [Jod-ch-09_229] (confidence: 0.944)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9636. INCORRECT [Jod-ch-09_230] (confidence: 0.952)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "18:00"}]
# --------------------------------------------------------------------------------
# 9637. INCORRECT [Jod-ch-09_231] (confidence: 0.958)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "20:30"}]
# --------------------------------------------------------------------------------
# 9638. INCORRECT [Jod-ch-09_232] (confidence: 0.966)
#  Answer given   : None
#  Correct answer : D
#  Raw response   : [{"answer_choice": "18:30"}]
# --------------------------------------------------------------------------------
# 9639. CORRECT [Jod-ch-09_233] (confidence: 0.926)
#  Answer given   : C
#  Correct answer : C
#  Raw response   : [{"answer_choice": "C"}]
# --------------------------------------------------------------------------------
# 9640. INCORRECT [Jod-ch-09_234] (confidence: 0.962)
#  Answer given   : None
#  Correct answer : C
#  Raw response   : [{"answer_choice": "20:30"}]
# --------------------------------------------------------------------------------
# 9664. CORRECT [Jod-ch-12_74] (confidence: 0.961)
#  Answer given   : D
#  Correct answer : D
#  Raw response   : [{"answer_choice": "D"}]
# --------------------------------------------------------------------------------
#
# ================================================================================
# MCQ EVALUATION RESULTS
# ================================================================================
# Accuracy: 55.02% (1837/3339)
# ================================================================================
#
# ================================================================================
# MCQ EVALUATION SUMMARY - ALL LOCALES
# ================================================================================
# Locale          Country         Correct    Total      Accuracy
# --------------------------------------------------------------------------------
# en-US           US              1658       1923        86.2%
# en-GB           UK              2068       2496        82.9%
# zh-CN           China           1628       2242        72.6%
# am-ET           Ethiopia        1837       3339        55.0%
# --------------------------------------------------------------------------------
# Overall         All             7191       10000       71.9%
# ================================================================================
#
# Best performing locale: 86.2%
#
# Performance gaps from best:
#   en-US: +0.0%
#   en-GB: +3.4%
#   zh-CN: +13.6%
#   am-ET: +31.2%

# %% [markdown]
# ## MCQ Failure Analysis
#
# Analyze incorrect predictions to try to understand the model's behaviour.

# %%
# MCQ Failure Analysis Across All Locales
print("\n" + "="*80)
print("MCQ FAILURE ANALYSIS - ALL LOCALES")
print("="*80)

for locale_code in LOCALES.keys():
    if locale_code not in mcq_results_by_locale:
        continue

    results = mcq_results_by_locale[locale_code]
    failures = [r for r in results if not r['is_correct']]

    print(f"\n{locale_code} ({LOCALES[locale_code]['name']}):")
    print("-"*80)
    print(f"Failures: {len(failures)}/{len(results)} ({len(failures)/len(results)*100:.1f}%)")

    if failures:
        # Show first 3 failures as examples
        print(f"\nExample failures (showing first 3):")
        for idx, fail in enumerate(failures[:3], 1):
            print(f"\n  {idx}. ID: {fail['mcqid']}")
            print(f"     Question: {fail['csv_prompt'][:100]}...")
            print(f"     Predicted: {fail['predicted_choice']} | Correct: {fail['correct_answer']}")
            print(f"     Confidence: {fail.get('confidence', 0.0):.3f}")

print("\n" + "="*80)
# Out:
# ================================================================================
# MCQ FAILURE ANALYSIS - ALL LOCALES
# ================================================================================
#
# en-US (English (United States)):
# --------------------------------------------------------------------------------
# Failures: 265/1923 (13.8%)
#
# Example failures (showing first 3):
#
#   1. ID: Al-en-01_169
#      Question: What is a common snack for preschool kids in the US? Without any explanation, choose only one from t...
#      Predicted: B | Correct: D
#      Confidence: 0.864
#
#   2. ID: Al-en-01_170
#      Question: What is a common snack for preschool kids in the US? Without any explanation, choose only one from t...
#      Predicted: B | Correct: D
#      Confidence: 0.905
#
#   3. ID: Al-en-01_175
#      Question: What is a common snack for preschool kids in the US? Without any explanation, choose only one from t...
#      Predicted: C | Correct: D
#      Confidence: 0.914
#
# en-GB (English (United Kingdom)):
# --------------------------------------------------------------------------------
# Failures: 428/2496 (17.1%)
#
# Example failures (showing first 3):
#
#   1. ID: Al-en-01_3
#      Question: What is a common snack for preschool kids in the UK? Without any explanation, choose only one from t...
#      Predicted: B | Correct: D
#      Confidence: 0.920
#
#   2. ID: Al-en-01_29
#      Question: What is a common snack for preschool kids in the UK? Without any explanation, choose only one from t...
#      Predicted: D | Correct: C
#      Confidence: 0.891
#
#   3. ID: Al-en-01_34
#      Question: What is a common snack for preschool kids in the UK? Without any explanation, choose only one from t...
#      Predicted: C | Correct: B
#      Confidence: 0.928
#
# zh-CN (Chinese (China)):
# --------------------------------------------------------------------------------
# Failures: 614/2242 (27.4%)
#
# Example failures (showing first 3):
#
#   1. ID: Al-en-04_38
#      Question: What is the most popular fruit in China? Without any explanation, choose only one from the given alp...
#      Predicted: C | Correct: D
#      Confidence: 0.902
#
#   2. ID: Al-en-04_39
#      Question: What is the most popular fruit in China? Without any explanation, choose only one from the given alp...
#      Predicted: B | Correct: D
#      Confidence: 0.953
#
#   3. ID: Al-en-04_41
#      Question: What is the most popular fruit in China? Without any explanation, choose only one from the given alp...
#      Predicted: B | Correct: D
#      Confidence: 0.915
#
# am-ET (Amharic (Ethiopia)):
# --------------------------------------------------------------------------------
# Failures: 1502/3339 (45.0%)
#
# Example failures (showing first 3):
#
#   1. ID: Al-en-01_957
#      Question: What is a common snack for preschool kids in Ethiopia? Without any explanation, choose only one from...
#      Predicted: C | Correct: D
#      Confidence: 0.973
#
#   2. ID: Al-en-01_958
#      Question: What is a common snack for preschool kids in Ethiopia? Without any explanation, choose only one from...
#      Predicted: C | Correct: D
#      Confidence: 0.975
#
#   3. ID: Al-en-01_959
#      Question: What is a common snack for preschool kids in Ethiopia? Without any explanation, choose only one from...
#      Predicted: C | Correct: D
#      Confidence: 0.978
#
# ================================================================================

# %% [markdown]
# ## MCQ Confidence Analysis
#
# Analyze confidence scores and abstention behavior for MCQ system.

# %%
# MCQ Confidence Analysis by Locale
print("\n" + "="*80)
print("MCQ CONFIDENCE ANALYSIS - BY LOCALE")
print("="*80)

for locale_code in LOCALES.keys():
    if locale_code not in mcq_results_by_locale:
        continue

    results = mcq_results_by_locale[locale_code]

    confidences = [r.get('confidence', 0.0) for r in results]
    correct_confidences = [r.get('confidence', 0.0) for r in results if r['is_correct']]
    incorrect_confidences = [r.get('confidence', 0.0) for r in results if not r['is_correct']]

    print(f"\n{locale_code} ({LOCALES[locale_code]['name']}):")
    print("-"*80)
    print(f"  Avg confidence (all): {np.mean(confidences):.3f}")
    if correct_confidences:
        print(f"  Avg confidence (correct): {np.mean(correct_confidences):.3f}")
    if incorrect_confidences:
        print(f"  Avg confidence (incorrect): {np.mean(incorrect_confidences):.3f}")

    # Abstention metrics
    abstained_count = sum(1 for r in results if r.get('abstained', False))
    answered_count = len(results) - abstained_count
    answered_correct = sum(1 for r in results if r['is_correct'] and not r.get('abstained', False))

    print(f"\n  Abstained: {abstained_count}/{len(results)} ({abstained_count/len(results)*100:.1f}%)")
    print(f"  Coverage (answered): {answered_count}/{len(results)} ({answered_count/len(results)*100:.1f}%)")
    if answered_count > 0:
        precision = answered_correct / answered_count * 100
        print(f"  Precision (on answered): {answered_correct}/{answered_count} ({precision:.1f}%)")
    else:
        print(f"  Precision (on answered): N/A (no questions answered)")

    if correct_confidences and incorrect_confidences:
        gap = np.mean(correct_confidences) - np.mean(incorrect_confidences)
        print(f"  Confidence gap: {gap:.3f}")

print("\n" + "="*80)
# Out:
# ================================================================================
# MCQ CONFIDENCE ANALYSIS - BY LOCALE
# ================================================================================
#
# en-US (English (United States)):
# --------------------------------------------------------------------------------
#   Avg confidence (all): 0.943
#   Avg confidence (correct): 0.947
#   Avg confidence (incorrect): 0.915
#
#   Abstained: 0/1923 (0.0%)
#   Coverage (answered): 1923/1923 (100.0%)
#   Precision (on answered): 1658/1923 (86.2%)
#   Confidence gap: 0.032
#
# en-GB (English (United Kingdom)):
# --------------------------------------------------------------------------------
#   Avg confidence (all): 0.948
#   Avg confidence (correct): 0.950
#   Avg confidence (incorrect): 0.936
#
#   Abstained: 0/2496 (0.0%)
#   Coverage (answered): 2496/2496 (100.0%)
#   Precision (on answered): 2068/2496 (82.9%)
#   Confidence gap: 0.014
#
# zh-CN (Chinese (China)):
# --------------------------------------------------------------------------------
#   Avg confidence (all): 0.947
#   Avg confidence (correct): 0.951
#   Avg confidence (incorrect): 0.937
#
#   Abstained: 0/2242 (0.0%)
#   Coverage (answered): 2242/2242 (100.0%)
#   Precision (on answered): 1628/2242 (72.6%)
#   Confidence gap: 0.014
#
# am-ET (Amharic (Ethiopia)):
# --------------------------------------------------------------------------------
#   Avg confidence (all): 0.953
#   Avg confidence (correct): 0.959
#   Avg confidence (incorrect): 0.947
#
#   Abstained: 0/3339 (0.0%)
#   Coverage (answered): 3339/3339 (100.0%)
#   Precision (on answered): 1837/3339 (55.0%)
#   Confidence gap: 0.012
#
# ================================================================================
